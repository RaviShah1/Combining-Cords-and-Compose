# %% [markdown]
# <a href="https://colab.research.google.com/github/RaviShah1/Combining-Cords-and-Compose/blob/main/experiments/resnet18_cifar10/cords_only_baseline.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/decile-team/cords.git
# %cd cords
# %ls
# Out:
# Cloning into 'cords'...
# remote: Enumerating objects: 4717, done.
# remote: Counting objects: 100% (20/20), done.
# remote: Compressing objects: 100% (20/20), done.
# remote: Total 4717 (delta 7), reused 0 (delta 0), pack-reused 4697
# Receiving objects: 100% (4717/4717), 58.34 MiB | 14.95 MiB/s, done.
# Resolving deltas: 100% (2867/2867), done.
# /content/cords
# benchmarks/   cords/     LICENSE.txt    setup.py      train_sl.py
# CITATION.CFF  docs/      README.md      tests/        train_ssl.py
# configs/      examples/  requirements/  train_hpo.py

# %%
# !pip install dotmap apricot-select ray[default] ray[tune] mosaicml
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting dotmap
#   Downloading dotmap-1.3.30-py3-none-any.whl (11 kB)
# Collecting apricot-select
#   Downloading apricot-select-0.6.1.tar.gz (28 kB)
# Collecting ray[default]
#   Downloading ray-1.13.0-cp37-cp37m-manylinux2014_x86_64.whl (54.5 MB)
#      |████████████████████████████████| 54.5 MB 133 kB/s
# Collecting mosaicml
#   Downloading mosaicml-0.8.0-py3-none-any.whl (548 kB)
#      |████████████████████████████████| 548 kB 69.1 MB/s
# Requirement already satisfied: numpy>=1.14.2 in /usr/local/lib/python3.7/dist-packages (from apricot-select) (1.21.6)
# Requirement already satisfied: scipy>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from apricot-select) (1.4.1)
# Requirement already satisfied: numba>=0.43.0 in /usr/local/lib/python3.7/dist-packages (from apricot-select) (0.51.2)
# Requirement already satisfied: tqdm>=4.24.0 in /usr/local/lib/python3.7/dist-packages (from apricot-select) (4.64.0)
# Collecting nose
#   Downloading nose-1.3.7-py3-none-any.whl (154 kB)
#      |████████████████████████████████| 154 kB 72.3 MB/s
# Requirement already satisfied: llvmlite<0.35,>=0.34.0.dev0 in /usr/local/lib/python3.7/dist-packages (from numba>=0.43.0->apricot-select) (0.34.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from numba>=0.43.0->apricot-select) (57.4.0)
# Requirement already satisfied: torchvision>=0.10.0 in /usr/local/lib/python3.7/dist-packages (from mosaicml) (0.12.0+cu113)
# Collecting pyyaml<7,>=6.0
#   Downloading PyYAML-6.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (596 kB)
#      |████████████████████████████████| 596 kB 22.3 MB/s
# Requirement already satisfied: torch<2,>=1.9 in /usr/local/lib/python3.7/dist-packages (from mosaicml) (1.11.0+cu113)
# Collecting psutil<6,>=5.8.0
#   Downloading psutil-5.9.1-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (281 kB)
#      |████████████████████████████████| 281 kB 76.2 MB/s
# Collecting coolname<2,>=1.1.0
#   Downloading coolname-1.1.0-py2.py3-none-any.whl (35 kB)
# Collecting torch-optimizer<0.2,>=0.1.0
#   Downloading torch_optimizer-0.1.0-py3-none-any.whl (72 kB)
#      |████████████████████████████████| 72 kB 1.2 MB/s
# Collecting py-cpuinfo>=8.0.0
#   Downloading py-cpuinfo-8.0.0.tar.gz (99 kB)
#      |████████████████████████████████| 99 kB 12.1 MB/s
# Collecting yahp<0.2,>=0.1.1
#   Downloading yahp-0.1.1-py3-none-any.whl (42 kB)
#      |████████████████████████████████| 42 kB 1.5 MB/s
# Collecting torchmetrics<0.8,>=0.7.0
#   Downloading torchmetrics-0.7.3-py3-none-any.whl (398 kB)
#      |████████████████████████████████| 398 kB 71.3 MB/s
# Collecting requests<3,>=2.26.0
#   Downloading requests-2.28.1-py3-none-any.whl (62 kB)
#      |████████████████████████████████| 62 kB 1.7 MB/s
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.26.0->mosaicml) (1.24.3)
# Requirement already satisfied: charset-normalizer<3,>=2 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.26.0->mosaicml) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.26.0->mosaicml) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.26.0->mosaicml) (2022.6.15)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch<2,>=1.9->mosaicml) (4.1.1)
# Collecting pytorch-ranger>=0.1.1
#   Downloading pytorch_ranger-0.1.1-py3-none-any.whl (14 kB)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from torchmetrics<0.8,>=0.7.0->mosaicml) (21.3)
# Collecting pyDeprecate==0.3.*
#   Downloading pyDeprecate-0.3.2-py3-none-any.whl (10 kB)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.7/dist-packages (from torchvision>=0.10.0->mosaicml) (7.1.2)
# Collecting ruamel.yaml>=0.17.10
#   Downloading ruamel.yaml-0.17.21-py3-none-any.whl (109 kB)
#      |████████████████████████████████| 109 kB 68.4 MB/s
# Collecting docstring-parser<=0.15,>=0.14.1
#   Downloading docstring_parser-0.14.1-py3-none-any.whl (33 kB)
# Collecting ruamel.yaml.clib>=0.2.6
#   Downloading ruamel.yaml.clib-0.2.6-cp37-cp37m-manylinux1_x86_64.whl (546 kB)
#      |████████████████████████████████| 546 kB 74.3 MB/s
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->torchmetrics<0.8,>=0.7.0->mosaicml) (3.0.9)
# Collecting grpcio<=1.43.0,>=1.28.1
#   Downloading grpcio-1.43.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.1 MB)
#      |████████████████████████████████| 4.1 MB 45.6 MB/s
# Requirement already satisfied: click<=8.0.4,>=7.0 in /usr/local/lib/python3.7/dist-packages (from ray[default]) (7.1.2)
# Requirement already satisfied: attrs in /usr/local/lib/python3.7/dist-packages (from ray[default]) (21.4.0)
# Collecting aiosignal
#   Downloading aiosignal-1.2.0-py3-none-any.whl (8.2 kB)
# Requirement already satisfied: jsonschema in /usr/local/lib/python3.7/dist-packages (from ray[default]) (4.3.3)
# Collecting frozenlist
#   Downloading frozenlist-1.3.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (144 kB)
#      |████████████████████████████████| 144 kB 79.0 MB/s
# Requirement already satisfied: protobuf<4.0.0,>=3.15.3 in /usr/local/lib/python3.7/dist-packages (from ray[default]) (3.17.3)
# Collecting virtualenv
#   Downloading virtualenv-20.15.1-py2.py3-none-any.whl (10.1 MB)
#      |████████████████████████████████| 10.1 MB 56.9 MB/s
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from ray[default]) (1.0.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from ray[default]) (3.7.1)
# Collecting opencensus
#   Downloading opencensus-0.9.0-py2.py3-none-any.whl (128 kB)
#      |████████████████████████████████| 128 kB 75.1 MB/s
# Collecting py-spy>=0.2.0
#   Downloading py_spy-0.3.12-py2.py3-none-manylinux_2_5_x86_64.manylinux1_x86_64.whl (3.1 MB)
#      |████████████████████████████████| 3.1 MB 58.3 MB/s
# Collecting colorful
#   Downloading colorful-0.5.4-py2.py3-none-any.whl (201 kB)
#      |████████████████████████████████| 201 kB 62.3 MB/s
# Collecting prometheus-client<0.14.0,>=0.7.1
#   Downloading prometheus_client-0.13.1-py3-none-any.whl (57 kB)
#      |████████████████████████████████| 57 kB 6.0 MB/s
# Requirement already satisfied: smart-open in /usr/local/lib/python3.7/dist-packages (from ray[default]) (5.2.1)
# Collecting aiohttp>=3.7
#   Downloading aiohttp-3.8.1-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 65.8 MB/s
# Collecting gpustat>=1.0.0b1
#   Downloading gpustat-1.0.0b1.tar.gz (82 kB)
#      |████████████████████████████████| 82 kB 321 kB/s
# Collecting aiohttp-cors
#   Downloading aiohttp_cors-0.7.0-py3-none-any.whl (27 kB)
# Collecting yarl<2.0,>=1.0
#   Downloading yarl-1.7.2-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (271 kB)
#      |████████████████████████████████| 271 kB 54.2 MB/s
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-6.0.2-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (94 kB)
#      |████████████████████████████████| 94 kB 3.1 MB/s
# Collecting asynctest==0.13.0
#   Downloading asynctest-0.13.0-py3-none-any.whl (26 kB)
# Collecting async-timeout<5.0,>=4.0.0a3
#   Downloading async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Requirement already satisfied: six>=1.7 in /usr/local/lib/python3.7/dist-packages (from gpustat>=1.0.0b1->ray[default]) (1.15.0)
# Collecting nvidia-ml-py3>=7.352.0
#   Downloading nvidia-ml-py3-7.352.0.tar.gz (19 kB)
# Collecting blessed>=1.17.1
#   Downloading blessed-1.19.1-py2.py3-none-any.whl (58 kB)
#      |████████████████████████████████| 58 kB 7.5 MB/s
# Requirement already satisfied: wcwidth>=0.1.4 in /usr/local/lib/python3.7/dist-packages (from blessed>=1.17.1->gpustat>=1.0.0b1->ray[default]) (0.2.5)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.7/dist-packages (from jsonschema->ray[default]) (0.18.1)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from jsonschema->ray[default]) (4.11.4)
# Requirement already satisfied: importlib-resources>=1.4.0 in /usr/local/lib/python3.7/dist-packages (from jsonschema->ray[default]) (5.7.1)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.7/dist-packages (from importlib-resources>=1.4.0->jsonschema->ray[default]) (3.8.0)
# Requirement already satisfied: google-api-core<3.0.0,>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from opencensus->ray[default]) (1.31.6)
# Collecting opencensus-context>=0.1.2
#   Downloading opencensus_context-0.1.2-py2.py3-none-any.whl (4.4 kB)
# Requirement already satisfied: pytz in /usr/local/lib/python3.7/dist-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->ray[default]) (2022.1)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->ray[default]) (1.56.2)
# Requirement already satisfied: google-auth<2.0dev,>=1.25.0 in /usr/local/lib/python3.7/dist-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->ray[default]) (1.35.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<2.0dev,>=1.25.0->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default]) (0.2.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<2.0dev,>=1.25.0->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default]) (4.2.4)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<2.0dev,>=1.25.0->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default]) (4.8)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<2.0dev,>=1.25.0->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default]) (0.4.8)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.7/dist-packages (from ray[default]) (0.8.9)
# Collecting tensorboardX>=1.9
#   Downloading tensorboardX-2.5.1-py2.py3-none-any.whl (125 kB)
#      |████████████████████████████████| 125 kB 73.8 MB/s
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from ray[default]) (1.3.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->ray[default]) (2.8.2)
# Collecting distlib<1,>=0.3.1
#   Downloading distlib-0.3.4-py2.py3-none-any.whl (461 kB)
#      |████████████████████████████████| 461 kB 77.6 MB/s
# Collecting platformdirs<3,>=2
#   Downloading platformdirs-2.5.2-py3-none-any.whl (14 kB)
# Building wheels for collected packages: apricot-select, py-cpuinfo, gpustat, nvidia-ml-py3
#   Building wheel for apricot-select (setup.py) ... done
#   Created wheel for apricot-select: filename=apricot_select-0.6.1-py3-none-any.whl size=48786 sha256=fec97ac4f996a25a7fb7b46d65432b3db36eac8e9e0d1169e647eb8758d7f8df
#   Stored in directory: /root/.cache/pip/wheels/1d/b0/5d/41bab30f23d17864700963dad70bbeda159a409e94f0778f2f
#   Building wheel for py-cpuinfo (setup.py) ... done
#   Created wheel for py-cpuinfo: filename=py_cpuinfo-8.0.0-py3-none-any.whl size=22257 sha256=faaf5c4aee66a2594beaf65719a976a7d103cbef971998d0e7be57bd8f58de6d
#   Stored in directory: /root/.cache/pip/wheels/d2/f1/1f/041add21dc9c4220157f1bd2bd6afe1f1a49524c3396b94401
#   Building wheel for gpustat (setup.py) ... done
#   Created wheel for gpustat: filename=gpustat-1.0.0b1-py3-none-any.whl size=15979 sha256=73dbf6faf57de8c3d669b1123781ba6f089f72cffa0b9049dda6bd08dc5388c9
#   Stored in directory: /root/.cache/pip/wheels/1a/16/e2/3e2437fba4c4b6a97a97bd96fce5d14e66cff5c4966fb1cc8c
#   Building wheel for nvidia-ml-py3 (setup.py) ... done
#   Created wheel for nvidia-ml-py3: filename=nvidia_ml_py3-7.352.0-py3-none-any.whl size=19190 sha256=a4ebe31c434d6da8cec6b2eb158cce9fafe6d06cf8db07aba1a74b64baf1503d
#   Stored in directory: /root/.cache/pip/wheels/df/99/da/c34f202dc8fd1dffd35e0ecf1a7d7f8374ca05fbcbaf974b83
# Successfully built apricot-select py-cpuinfo gpustat nvidia-ml-py3
# Installing collected packages: multidict, frozenlist, yarl, ruamel.yaml.clib, requests, platformdirs, distlib, asynctest, async-timeout, aiosignal, virtualenv, ruamel.yaml, pyyaml, pytorch-ranger, pyDeprecate, psutil, opencensus-context, nvidia-ml-py3, grpcio, docstring-parser, blessed, aiohttp, yahp, torchmetrics, torch-optimizer, tensorboardX, ray, py-spy, py-cpuinfo, prometheus-client, opencensus, nose, gpustat, coolname, colorful, aiohttp-cors, mosaicml, dotmap, apricot-select
#   Attempting uninstall: requests
#     Found existing installation: requests 2.23.0
#     Uninstalling requests-2.23.0:
#       Successfully uninstalled requests-2.23.0
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
#   Attempting uninstall: psutil
#     Found existing installation: psutil 5.4.8
#     Uninstalling psutil-5.4.8:
#       Successfully uninstalled psutil-5.4.8
#   Attempting uninstall: grpcio
#     Found existing installation: grpcio 1.46.3
#     Uninstalling grpcio-1.46.3:
#       Successfully uninstalled grpcio-1.46.3
#   Attempting uninstall: prometheus-client
#     Found existing installation: prometheus-client 0.14.1
#     Uninstalling prometheus-client-0.14.1:
#       Successfully uninstalled prometheus-client-0.14.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires requests~=2.23.0, but you have requests 2.28.1 which is incompatible.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# Successfully installed aiohttp-3.8.1 aiohttp-cors-0.7.0 aiosignal-1.2.0 apricot-select-0.6.1 async-timeout-4.0.2 asynctest-0.13.0 blessed-1.19.1 colorful-0.5.4 coolname-1.1.0 distlib-0.3.4 docstring-parser-0.14.1 dotmap-1.3.30 frozenlist-1.3.0 gpustat-1.0.0b1 grpcio-1.43.0 mosaicml-0.8.0 multidict-6.0.2 nose-1.3.7 nvidia-ml-py3-7.352.0 opencensus-0.9.0 opencensus-context-0.1.2 platformdirs-2.5.2 prometheus-client-0.13.1 psutil-5.9.1 py-cpuinfo-8.0.0 py-spy-0.3.12 pyDeprecate-0.3.2 pytorch-ranger-0.1.1 pyyaml-6.0 ray-1.13.0 requests-2.28.1 ruamel.yaml-0.17.21 ruamel.yaml.clib-0.2.6 tensorboardX-2.5.1 torch-optimizer-0.1.0 torchmetrics-0.7.3 virtualenv-20.15.1 yahp-0.1.1 yarl-1.7.2

# %%
import time
import numpy as np
import os
import torch
import torch.nn as nn
import torch.optim as optim
from cords.utils.data.datasets.SL import gen_dataset
from torch.utils.data import Subset
from cords.utils.config_utils import load_config_data
import os.path as osp
from cords.utils.data.data_utils import WeightedSubset
from composer import functional as cf
from ray import tune

# %%
trainset, validset, testset, num_cls = gen_dataset('data/', 'cifar10', None, isnumpy=False)
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to data/cifar-10-python.tar.gz
#   0%|          | 0/170498071 [00:00<?, ?it/s]
# Extracting data/cifar-10-python.tar.gz to data/
# Files already downloaded and verified

# %%
trn_batch_size = 20
val_batch_size = 20
tst_batch_size = 1000

# Creating the Data Loaders
trainloader = torch.utils.data.DataLoader(trainset, batch_size=trn_batch_size,
                                          shuffle=False, pin_memory=True)

valloader = torch.utils.data.DataLoader(validset, batch_size=val_batch_size,
                                        shuffle=False, pin_memory=True)

testloader = torch.utils.data.DataLoader(testset, batch_size=tst_batch_size,
                                          shuffle=False, pin_memory=True)

# %%
from cords.utils.models import ResNet18
numclasses = 10
device = 'cuda' #Device Argument
model = ResNet18(10)
model = model.to(device)

# %%
criterion = nn.CrossEntropyLoss()
criterion_nored = nn.CrossEntropyLoss(reduction='none')

# %%
def save_ckpt(state, ckpt_path):
    torch.save(state, ckpt_path)


def load_ckpt(ckpt_path, model, optimizer):
    checkpoint = torch.load(ckpt_path)
    start_epoch = checkpoint['epoch']
    model.load_state_dict(checkpoint['state_dict'])
    optimizer.load_state_dict(checkpoint['optimizer'])
    loss = checkpoint['loss']
    metrics = checkpoint['metrics']
    return start_epoch, model, optimizer, loss, metrics

# %%
def generate_cumulative_timing(mod_timing):
    tmp = 0
    mod_cum_timing = np.zeros(len(mod_timing))
    for i in range(len(mod_timing)):
        tmp += mod_timing[i]
        mod_cum_timing[i] = tmp
    return mod_cum_timing / 3600

# %%
optimizer = optim.SGD(model.parameters(), lr=1e-2,
                                  momentum=0.9,
                                  weight_decay=5e-4,
                                  nesterov=False)

#T_max is the maximum number of scheduler steps. Here we are using the number of epochs as the maximum number of scheduler steps.

scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer,
                                                       T_max=300)

# %%
def __get_logger(results_dir):
  os.makedirs(results_dir, exist_ok=True)
  # setup logger
  plain_formatter = logging.Formatter("[%(asctime)s] %(name)s %(levelname)s: %(message)s",
                                      datefmt="%m/%d %H:%M:%S")
  logger = logging.getLogger(__name__)
  logger.setLevel(logging.INFO)
  s_handler = logging.StreamHandler(stream=sys.stdout)
  s_handler.setFormatter(plain_formatter)
  s_handler.setLevel(logging.INFO)
  logger.addHandler(s_handler)
  f_handler = logging.FileHandler(os.path.join(results_dir, "results.log"))
  f_handler.setFormatter(plain_formatter)
  f_handler.setLevel(logging.DEBUG)
  logger.addHandler(f_handler)
  logger.propagate = False
  return logger

# %%
import logging
import os
import os.path as osp
import sys

#Results logging directory
results_dir = osp.abspath(osp.expanduser('results'))
logger = __get_logger(results_dir)

# %%
logger.info("hello")
# Out:
# [07/03 21:46:00] __main__ INFO: hello

# %%
from cords.utils.data.dataloader.SL.adaptive import GLISTERDataLoader, OLRandomDataLoader, \
    CRAIGDataLoader, GradMatchDataLoader, RandomDataLoader
from dotmap import DotMap

selection_strategy = 'GLISTER'
dss_args = dict(model=model,
                loss=criterion_nored,
                eta=0.01,
                num_classes=10,
                num_epochs=300,
                device='cuda',
                fraction=0.1,
                select_every=20,
                kappa=0,
                linear_layer=False,
                selection_type='SL',
                greedy='Stochastic')
dss_args = DotMap(dss_args)

dataloader = GLISTERDataLoader(trainloader, valloader, dss_args, logger, 
                                  batch_size=20, 
                                  shuffle=True,
                                  pin_memory=False)
# Out:
# /usr/local/lib/python3.7/dist-packages/numba/np/ufunc/parallel.py:363: NumbaWarning: The TBB threading layer requires TBB version 2019.5 or later i.e., TBB_INTERFACE_VERSION >= 11005. Found TBB_INTERFACE_VERSION = 9107. The TBB threading layer is disabled.
#   warnings.warn(problem)

# %%
#Training Arguments
num_epochs = 100

#Arguments for results logging
print_every = 1
print_args = ["val_loss", "val_acc", "tst_loss", "tst_acc", "time"]

#Argumets for checkpointing
save_every = 20
is_save = True

#Evaluation Metrics
trn_losses = list()
val_losses = list()
tst_losses = list()
subtrn_losses = list()
timing = list()
trn_acc = list()
val_acc = list()  
tst_acc = list()  
subtrn_acc = list()

# %%
"""
################################################# Training Loop #################################################
"""
for epoch in range(num_epochs):
    subtrn_loss = 0
    subtrn_correct = 0
    subtrn_total = 0
    model.train()
    start_time = time.time()
    for _, (inputs, targets, weights) in enumerate(dataloader):
        inputs = inputs.to(device)
        targets = targets.to(device, non_blocking=True)
        weights = weights.to(device)  
        optimizer.zero_grad()
        outputs = model(inputs)
        losses = criterion_nored(outputs, targets)
        loss = torch.dot(losses, weights/(weights.sum()))
        loss.backward()
        subtrn_loss += loss.item()
        optimizer.step()
        _, predicted = outputs.max(1)
        subtrn_total += targets.size(0)
        subtrn_correct += predicted.eq(targets).sum().item()
    epoch_time = time.time() - start_time
    scheduler.step()
    timing.append(epoch_time)


    """
    ################################################# Evaluation Loop #################################################
    """

    if (epoch + 1) % print_every == 0:
        trn_loss = 0
        trn_correct = 0
        trn_total = 0
        val_loss = 0
        val_correct = 0
        val_total = 0
        tst_correct = 0
        tst_total = 0
        tst_loss = 0
        model.eval()

        if ("trn_loss" in print_args) or ("trn_acc" in print_args):
            with torch.no_grad():
                for _, (inputs, targets) in enumerate(trainloader):
                    inputs, targets = inputs.to(device), \
                                      targets.to(device, non_blocking=True)
                    #Mix Up
                    inputs_mixed, targets_perm, mixing = cf.mixup_batch(inputs, targets, alpha=0.2)
                    targets_mixed = (1 - mixing) * targets + mixing * targets_perm
                    outputs = model(inputs_mixed)
                    #Label Smoothing
                    smoothed_targets_mixed = cf.smooth_labels(outputs, targets_mixed, smoothing=0.1)
                    loss = criterion(outputs, smoothed_targets_mixed)
                    trn_loss += loss.item()
                    if "trn_acc" in print_args:
                        _, predicted = outputs.max(1)
                        trn_total += targets.size(0)
                        trn_correct += predicted.eq(targets).sum().item()
                trn_losses.append(trn_loss)

            if "trn_acc" in print_args:
                trn_acc.append(trn_correct / trn_total)

        if ("val_loss" in print_args) or ("val_acc" in print_args):
            with torch.no_grad():
                for _, (inputs, targets) in enumerate(valloader):
                    inputs, targets = inputs.to(device), \
                                      targets.to(device, non_blocking=True)
                    outputs = model(inputs)
                    loss = criterion(outputs, targets)
                    val_loss += loss.item()
                    if "val_acc" in print_args:
                        _, predicted = outputs.max(1)
                        val_total += targets.size(0)
                        val_correct += predicted.eq(targets).sum().item()
                val_losses.append(val_loss)

            if "val_acc" in print_args:
                val_acc.append(val_correct / val_total)

        if ("tst_loss" in print_args) or ("tst_acc" in print_args):
            with torch.no_grad():
                for _, (inputs, targets) in enumerate(testloader):
                    inputs, targets = inputs.to(device), \
                                      targets.to(device, non_blocking=True)
                    outputs = model(inputs)
                    loss = criterion(outputs, targets)
                    tst_loss += loss.item()
                    if "tst_acc" in print_args:
                        _, predicted = outputs.max(1)
                        tst_total += targets.size(0)
                        tst_correct += predicted.eq(targets).sum().item()
                tst_losses.append(tst_loss)

            if "tst_acc" in print_args:
                tst_acc.append(tst_correct / tst_total)

        if "subtrn_acc" in print_args:
            subtrn_acc.append(subtrn_correct / subtrn_total)

        if "subtrn_losses" in print_args:
            subtrn_losses.append(subtrn_loss)

        print_str = "Epoch: " + str(epoch + 1)

        """
        ################################################# Results Printing #################################################
        """

        for arg in print_args:

            if arg == "val_loss":
                print_str += " , " + "Validation Loss: " + str(val_losses[-1])

            if arg == "val_acc":
                print_str += " , " + "Validation Accuracy: " + str(val_acc[-1])

            if arg == "tst_loss":
                print_str += " , " + "Test Loss: " + str(tst_losses[-1])

            if arg == "tst_acc":
                print_str += " , " + "Test Accuracy: " + str(tst_acc[-1])

            if arg == "trn_loss":
                print_str += " , " + "Training Loss: " + str(trn_losses[-1])

            if arg == "trn_acc":
                print_str += " , " + "Training Accuracy: " + str(trn_acc[-1])

            if arg == "subtrn_loss":
                print_str += " , " + "Subset Loss: " + str(subtrn_losses[-1])

            if arg == "subtrn_acc":
                print_str += " , " + "Subset Accuracy: " + str(subtrn_acc[-1])

            if arg == "time":
                print_str += " , " + "Timing: " + str(timing[-1])

        logger.info(print_str)

    """
    ################################################# Checkpoint Saving #################################################
    """

    if ((epoch + 1) % save_every == 0) and is_save:

        metric_dict = {}

        for arg in print_args:
            if arg == "val_loss":
                metric_dict['val_loss'] = val_losses
            if arg == "val_acc":
                metric_dict['val_acc'] = val_acc
            if arg == "tst_loss":
                metric_dict['tst_loss'] = tst_losses
            if arg == "tst_acc":
                metric_dict['tst_acc'] = tst_acc
            if arg == "trn_loss":
                metric_dict['trn_loss'] = trn_losses
            if arg == "trn_acc":
                metric_dict['trn_acc'] = trn_acc
            if arg == "subtrn_loss":
                metric_dict['subtrn_loss'] = subtrn_losses
            if arg == "subtrn_acc":
                metric_dict['subtrn_acc'] = subtrn_acc
            if arg == "time":
                metric_dict['time'] = timing

        ckpt_state = {
            'epoch': epoch + 1,
            'state_dict': model.state_dict(),
            'optimizer': optimizer.state_dict(),
            'loss': criterion_nored,
            'metrics': metric_dict
        }

        # save checkpoint
        save_ckpt(ckpt_state, 'model.pt')
        logger.info("Model checkpoint saved at epoch: {0:d}".format(epoch + 1))

"""
################################################# Results Summary #################################################
"""

logger.info("{0:s} Selection Run---------------------------------".format(selection_strategy))
logger.info("Final SubsetTrn: {0:f}".format(subtrn_loss))
if "val_loss" in print_args:
    if "val_acc" in print_args:
        logger.info("Validation Loss: %.2f , Validation Accuracy: %.2f", val_loss, val_acc[-1])
    else:
        logger.info("Validation Loss: %.2f", val_loss)

if "tst_loss" in print_args:
    if "tst_acc" in print_args:
        logger.info("Test Loss: %.2f, Test Accuracy: %.2f", tst_loss, tst_acc[-1])
    else:
        logger.info("Test Data Loss: %f", tst_loss)
logger.info('---------------------------------------------------------------------')
logger.info(selection_strategy)
logger.info('---------------------------------------------------------------------')

"""
################################################# Final Results Logging #################################################
"""

if "val_acc" in print_args:
    val_str = "Validation Accuracy, "
    for val in val_acc:
        val_str = val_str + " , " + str(val)
    logger.info(val_str)

if "tst_acc" in print_args:
    tst_str = "Test Accuracy, "
    for tst in tst_acc:
        tst_str = tst_str + " , " + str(tst)
    logger.info(tst_str)

if "time" in print_args:
    time_str = "Time, "
    for t in timing:
        time_str = time_str + " , " + str(t)
    logger.info(timing)

timing_array = np.array(timing)
cum_timing = list(generate_cumulative_timing(timing_array))
logger.info("Total time taken by %s = %.4f ", selection_strategy, cum_timing[-1])
# Out:
# [07/03 21:56:26] __main__ INFO: Epoch: 1 , Validation Loss: 189.1929834485054 , Validation Accuracy: 0.734 , Test Loss: 7.311197638511658 , Test Accuracy: 0.7405 , Timing: 6.224469184875488
# [07/03 21:56:39] __main__ INFO: Epoch: 2 , Validation Loss: 236.17034327983856 , Validation Accuracy: 0.6692 , Test Loss: 8.976239562034607 , Test Accuracy: 0.6906 , Timing: 6.194570779800415
# [07/03 21:56:52] __main__ INFO: Epoch: 3 , Validation Loss: 213.02516049146652 , Validation Accuracy: 0.6936 , Test Loss: 8.253830909729004 , Test Accuracy: 0.7128 , Timing: 6.205414772033691
# [07/03 21:57:04] __main__ INFO: Epoch: 4 , Validation Loss: 211.46410778164864 , Validation Accuracy: 0.701 , Test Loss: 8.305358529090881 , Test Accuracy: 0.7144 , Timing: 6.1725358963012695
# [07/03 21:57:17] __main__ INFO: Epoch: 5 , Validation Loss: 192.07019859552383 , Validation Accuracy: 0.7262 , Test Loss: 7.595928311347961 , Test Accuracy: 0.7391 , Timing: 6.146477460861206
# [07/03 21:57:30] __main__ INFO: Epoch: 6 , Validation Loss: 200.7090274244547 , Validation Accuracy: 0.7302 , Test Loss: 8.005065143108368 , Test Accuracy: 0.7368 , Timing: 6.173302173614502
# [07/03 21:57:43] __main__ INFO: Epoch: 7 , Validation Loss: 193.390543743968 , Validation Accuracy: 0.737 , Test Loss: 7.7230610847473145 , Test Accuracy: 0.746 , Timing: 6.173976182937622
# [07/03 21:57:56] __main__ INFO: Epoch: 8 , Validation Loss: 199.41330552101135 , Validation Accuracy: 0.7234 , Test Loss: 7.859446346759796 , Test Accuracy: 0.7367 , Timing: 6.176623344421387
# [07/03 21:58:08] __main__ INFO: Epoch: 9 , Validation Loss: 190.8074515759945 , Validation Accuracy: 0.737 , Test Loss: 7.582543194293976 , Test Accuracy: 0.7497 , Timing: 6.20458984375
# [07/03 21:58:21] __main__ INFO: Epoch: 10 , Validation Loss: 229.0582077205181 , Validation Accuracy: 0.7088 , Test Loss: 9.591266989707947 , Test Accuracy: 0.7219 , Timing: 6.239851951599121
# [07/03 21:58:34] __main__ INFO: Epoch: 11 , Validation Loss: 207.94892740249634 , Validation Accuracy: 0.7252 , Test Loss: 8.392832279205322 , Test Accuracy: 0.7301 , Timing: 6.1872429847717285
# [07/03 21:58:47] __main__ INFO: Epoch: 12 , Validation Loss: 227.98160660266876 , Validation Accuracy: 0.7104 , Test Loss: 9.069023609161377 , Test Accuracy: 0.7264 , Timing: 6.164392471313477
# [07/03 21:59:00] __main__ INFO: Epoch: 13 , Validation Loss: 207.2879565358162 , Validation Accuracy: 0.736 , Test Loss: 8.529821276664734 , Test Accuracy: 0.7401 , Timing: 6.153202533721924
# [07/03 21:59:13] __main__ INFO: Epoch: 14 , Validation Loss: 191.31809158623219 , Validation Accuracy: 0.7518 , Test Loss: 7.990853130817413 , Test Accuracy: 0.7459 , Timing: 6.476832389831543
# [07/03 21:59:26] __main__ INFO: Epoch: 15 , Validation Loss: 205.8148029744625 , Validation Accuracy: 0.7502 , Test Loss: 8.197858273983002 , Test Accuracy: 0.7566 , Timing: 6.182268381118774
# [07/03 21:59:38] __main__ INFO: Epoch: 16 , Validation Loss: 293.6244478225708 , Validation Accuracy: 0.675 , Test Loss: 11.64171850681305 , Test Accuracy: 0.6921 , Timing: 6.228482723236084
# [07/03 21:59:51] __main__ INFO: Epoch: 17 , Validation Loss: 204.58740444481373 , Validation Accuracy: 0.735 , Test Loss: 8.4766765832901 , Test Accuracy: 0.7454 , Timing: 6.206922769546509
# [07/03 22:00:04] __main__ INFO: Epoch: 18 , Validation Loss: 219.49801716953516 , Validation Accuracy: 0.7222 , Test Loss: 8.923488557338715 , Test Accuracy: 0.7341 , Timing: 6.140637159347534
# [07/03 22:00:17] __main__ INFO: Epoch: 19 , Validation Loss: 240.36398426443338 , Validation Accuracy: 0.7064 , Test Loss: 9.770763635635376 , Test Accuracy: 0.7289 , Timing: 6.1667046546936035
# [07/03 22:00:50] __main__ INFO: Epoch: 61, GLISTER dataloader subset selection finished, takes 33.3843.
# [07/03 22:01:03] __main__ INFO: Epoch: 20 , Validation Loss: 177.03340846300125 , Validation Accuracy: 0.7458 , Test Loss: 7.109109044075012 , Test Accuracy: 0.7519 , Timing: 39.64784622192383
# [07/03 22:01:03] __main__ INFO: Model checkpoint saved at epoch: 20
# [07/03 22:01:16] __main__ INFO: Epoch: 21 , Validation Loss: 164.20583620667458 , Validation Accuracy: 0.7618 , Test Loss: 6.817995727062225 , Test Accuracy: 0.7584 , Timing: 6.3326098918914795
# [07/03 22:01:29] __main__ INFO: Epoch: 22 , Validation Loss: 166.8858950138092 , Validation Accuracy: 0.761 , Test Loss: 6.732303440570831 , Test Accuracy: 0.7602 , Timing: 6.18815541267395
# [07/03 22:01:42] __main__ INFO: Epoch: 23 , Validation Loss: 173.90540298819542 , Validation Accuracy: 0.7542 , Test Loss: 6.988805770874023 , Test Accuracy: 0.7615 , Timing: 6.2116546630859375
# [07/03 22:01:55] __main__ INFO: Epoch: 24 , Validation Loss: 173.48072607815266 , Validation Accuracy: 0.7558 , Test Loss: 7.01126903295517 , Test Accuracy: 0.7571 , Timing: 6.184006452560425
# [07/03 22:02:08] __main__ INFO: Epoch: 25 , Validation Loss: 159.9615067690611 , Validation Accuracy: 0.7744 , Test Loss: 6.196364223957062 , Test Accuracy: 0.7824 , Timing: 6.205666542053223
# [07/03 22:02:21] __main__ INFO: Epoch: 26 , Validation Loss: 197.2740569859743 , Validation Accuracy: 0.7234 , Test Loss: 8.0053071975708 , Test Accuracy: 0.7356 , Timing: 6.180716276168823
# [07/03 22:02:34] __main__ INFO: Epoch: 27 , Validation Loss: 167.64359015226364 , Validation Accuracy: 0.7648 , Test Loss: 6.8340259194374084 , Test Accuracy: 0.7708 , Timing: 6.255231857299805
# [07/03 22:02:46] __main__ INFO: Epoch: 28 , Validation Loss: 206.2770890146494 , Validation Accuracy: 0.7286 , Test Loss: 8.383487462997437 , Test Accuracy: 0.741 , Timing: 6.227575778961182
# [07/03 22:02:59] __main__ INFO: Epoch: 29 , Validation Loss: 203.36633832007647 , Validation Accuracy: 0.7342 , Test Loss: 8.459568202495575 , Test Accuracy: 0.7372 , Timing: 6.1820783615112305
# [07/03 22:03:12] __main__ INFO: Epoch: 30 , Validation Loss: 198.26915645599365 , Validation Accuracy: 0.7398 , Test Loss: 7.752084970474243 , Test Accuracy: 0.7516 , Timing: 6.184403896331787
# [07/03 22:03:25] __main__ INFO: Epoch: 31 , Validation Loss: 227.4590124413371 , Validation Accuracy: 0.7262 , Test Loss: 9.690704822540283 , Test Accuracy: 0.72 , Timing: 6.168573617935181
# [07/03 22:03:38] __main__ INFO: Epoch: 32 , Validation Loss: 187.43948103487492 , Validation Accuracy: 0.766 , Test Loss: 7.995353043079376 , Test Accuracy: 0.7573 , Timing: 6.4507434368133545
# [07/03 22:03:51] __main__ INFO: Epoch: 33 , Validation Loss: 193.74236291646957 , Validation Accuracy: 0.755 , Test Loss: 8.191238343715668 , Test Accuracy: 0.7597 , Timing: 6.19563364982605
# [07/03 22:04:04] __main__ INFO: Epoch: 34 , Validation Loss: 166.29096306860447 , Validation Accuracy: 0.7812 , Test Loss: 7.016613602638245 , Test Accuracy: 0.7865 , Timing: 6.215059041976929
# [07/03 22:04:17] __main__ INFO: Epoch: 35 , Validation Loss: 236.08624140918255 , Validation Accuracy: 0.7308 , Test Loss: 10.293311595916748 , Test Accuracy: 0.7231 , Timing: 6.259663343429565
# [07/03 22:04:29] __main__ INFO: Epoch: 36 , Validation Loss: 218.65008832514286 , Validation Accuracy: 0.7438 , Test Loss: 8.704285621643066 , Test Accuracy: 0.7612 , Timing: 6.192409992218018
# [07/03 22:04:42] __main__ INFO: Epoch: 37 , Validation Loss: 214.97208731621504 , Validation Accuracy: 0.735 , Test Loss: 9.019010961055756 , Test Accuracy: 0.7384 , Timing: 6.17082667350769
# [07/03 22:04:55] __main__ INFO: Epoch: 38 , Validation Loss: 223.57288862764835 , Validation Accuracy: 0.733 , Test Loss: 9.736153364181519 , Test Accuracy: 0.7367 , Timing: 6.148425579071045
# [07/03 22:05:08] __main__ INFO: Epoch: 39 , Validation Loss: 218.8162386417389 , Validation Accuracy: 0.7366 , Test Loss: 9.657558739185333 , Test Accuracy: 0.7313 , Timing: 6.156507968902588
# [07/03 22:05:41] __main__ INFO: Epoch: 81, GLISTER dataloader subset selection finished, takes 32.7600.
# [07/03 22:05:53] __main__ INFO: Epoch: 40 , Validation Loss: 149.99468755722046 , Validation Accuracy: 0.7886 , Test Loss: 5.949261426925659 , Test Accuracy: 0.7935 , Timing: 38.993733644485474
# [07/03 22:05:54] __main__ INFO: Model checkpoint saved at epoch: 40
# [07/03 22:06:06] __main__ INFO: Epoch: 41 , Validation Loss: 174.36759175360203 , Validation Accuracy: 0.7542 , Test Loss: 7.038131058216095 , Test Accuracy: 0.7589 , Timing: 6.161468744277954
# [07/03 22:06:19] __main__ INFO: Epoch: 42 , Validation Loss: 157.0239630639553 , Validation Accuracy: 0.7716 , Test Loss: 6.418744623661041 , Test Accuracy: 0.7756 , Timing: 6.143886089324951
# [07/03 22:06:32] __main__ INFO: Epoch: 43 , Validation Loss: 156.05997157096863 , Validation Accuracy: 0.7874 , Test Loss: 6.240271210670471 , Test Accuracy: 0.7866 , Timing: 6.1695778369903564
# [07/03 22:06:45] __main__ INFO: Epoch: 44 , Validation Loss: 161.28475143015385 , Validation Accuracy: 0.7818 , Test Loss: 6.262784957885742 , Test Accuracy: 0.7916 , Timing: 6.168063163757324
# [07/03 22:06:58] __main__ INFO: Epoch: 45 , Validation Loss: 169.2126538977027 , Validation Accuracy: 0.7698 , Test Loss: 6.347184598445892 , Test Accuracy: 0.7848 , Timing: 6.193114995956421
# [07/03 22:07:11] __main__ INFO: Epoch: 46 , Validation Loss: 182.77550315856934 , Validation Accuracy: 0.7672 , Test Loss: 7.372164249420166 , Test Accuracy: 0.7724 , Timing: 6.228784084320068
# [07/03 22:07:23] __main__ INFO: Epoch: 47 , Validation Loss: 169.3129710778594 , Validation Accuracy: 0.7846 , Test Loss: 7.18661767244339 , Test Accuracy: 0.784 , Timing: 6.19180154800415
# [07/03 22:07:36] __main__ INFO: Epoch: 48 , Validation Loss: 164.66835891455412 , Validation Accuracy: 0.784 , Test Loss: 6.493658721446991 , Test Accuracy: 0.7918 , Timing: 6.140308618545532
# [07/03 22:07:49] __main__ INFO: Epoch: 49 , Validation Loss: 155.283209502697 , Validation Accuracy: 0.7988 , Test Loss: 6.349279046058655 , Test Accuracy: 0.8055 , Timing: 6.1957197189331055
# [07/03 22:08:02] __main__ INFO: Epoch: 50 , Validation Loss: 160.5175670236349 , Validation Accuracy: 0.7992 , Test Loss: 6.627334117889404 , Test Accuracy: 0.8057 , Timing: 6.366339683532715
# [07/03 22:08:15] __main__ INFO: Epoch: 51 , Validation Loss: 188.739782653749 , Validation Accuracy: 0.7698 , Test Loss: 8.051574528217316 , Test Accuracy: 0.7685 , Timing: 6.156532526016235
# [07/03 22:08:28] __main__ INFO: Epoch: 52 , Validation Loss: 177.28002920746803 , Validation Accuracy: 0.7846 , Test Loss: 7.785381317138672 , Test Accuracy: 0.7774 , Timing: 6.24145770072937
# [07/03 22:08:41] __main__ INFO: Epoch: 53 , Validation Loss: 164.9237431138754 , Validation Accuracy: 0.7932 , Test Loss: 6.865785896778107 , Test Accuracy: 0.7951 , Timing: 6.199109792709351
# [07/03 22:08:53] __main__ INFO: Epoch: 54 , Validation Loss: 165.0589096173644 , Validation Accuracy: 0.7942 , Test Loss: 6.911724865436554 , Test Accuracy: 0.8074 , Timing: 6.220349311828613
# [07/03 22:09:06] __main__ INFO: Epoch: 55 , Validation Loss: 180.48591844178736 , Validation Accuracy: 0.7854 , Test Loss: 7.315764904022217 , Test Accuracy: 0.7941 , Timing: 6.169164180755615
# [07/03 22:09:19] __main__ INFO: Epoch: 56 , Validation Loss: 197.40116867423058 , Validation Accuracy: 0.7636 , Test Loss: 7.563517153263092 , Test Accuracy: 0.7818 , Timing: 6.157003879547119
# [07/03 22:09:32] __main__ INFO: Epoch: 57 , Validation Loss: 180.36698009818792 , Validation Accuracy: 0.7874 , Test Loss: 7.025280952453613 , Test Accuracy: 0.7983 , Timing: 6.160642147064209
# [07/03 22:09:45] __main__ INFO: Epoch: 58 , Validation Loss: 183.4230978488922 , Validation Accuracy: 0.7876 , Test Loss: 7.263565838336945 , Test Accuracy: 0.8 , Timing: 6.1885809898376465
# [07/03 22:09:57] __main__ INFO: Epoch: 59 , Validation Loss: 218.1935872361064 , Validation Accuracy: 0.7484 , Test Loss: 9.290013432502747 , Test Accuracy: 0.7528 , Timing: 6.229471921920776
# [07/03 22:10:30] __main__ INFO: Epoch: 101, GLISTER dataloader subset selection finished, takes 32.5870.
# [07/03 22:10:43] __main__ INFO: Epoch: 60 , Validation Loss: 141.38269449025393 , Validation Accuracy: 0.8034 , Test Loss: 5.36689430475235 , Test Accuracy: 0.8165 , Timing: 38.77840065956116
# [07/03 22:10:43] __main__ INFO: Model checkpoint saved at epoch: 60
# [07/03 22:10:56] __main__ INFO: Epoch: 61 , Validation Loss: 140.64197923243046 , Validation Accuracy: 0.802 , Test Loss: 5.574084758758545 , Test Accuracy: 0.8042 , Timing: 6.14604377746582
# [07/03 22:11:09] __main__ INFO: Epoch: 62 , Validation Loss: 148.36305686831474 , Validation Accuracy: 0.7992 , Test Loss: 5.946977853775024 , Test Accuracy: 0.8018 , Timing: 6.187392950057983
# [07/03 22:11:21] __main__ INFO: Epoch: 63 , Validation Loss: 142.32780510932207 , Validation Accuracy: 0.8096 , Test Loss: 5.708697140216827 , Test Accuracy: 0.8106 , Timing: 6.146167039871216
# [07/03 22:11:34] __main__ INFO: Epoch: 64 , Validation Loss: 162.05542434751987 , Validation Accuracy: 0.7876 , Test Loss: 6.3538126945495605 , Test Accuracy: 0.799 , Timing: 6.172006607055664
# [07/03 22:11:47] __main__ INFO: Epoch: 65 , Validation Loss: 143.32346792519093 , Validation Accuracy: 0.8118 , Test Loss: 5.8234845995903015 , Test Accuracy: 0.8129 , Timing: 6.1962504386901855
# [07/03 22:12:00] __main__ INFO: Epoch: 66 , Validation Loss: 162.53079609572887 , Validation Accuracy: 0.7892 , Test Loss: 6.512593030929565 , Test Accuracy: 0.7973 , Timing: 6.159686088562012
# [07/03 22:12:13] __main__ INFO: Epoch: 67 , Validation Loss: 160.0786636173725 , Validation Accuracy: 0.7948 , Test Loss: 6.353812336921692 , Test Accuracy: 0.8006 , Timing: 6.148575305938721
# [07/03 22:12:26] __main__ INFO: Epoch: 68 , Validation Loss: 169.2797578126192 , Validation Accuracy: 0.7922 , Test Loss: 6.9734591245651245 , Test Accuracy: 0.7913 , Timing: 6.165439128875732
# [07/03 22:12:39] __main__ INFO: Epoch: 69 , Validation Loss: 191.2044214606285 , Validation Accuracy: 0.7672 , Test Loss: 7.712662220001221 , Test Accuracy: 0.7767 , Timing: 6.170447587966919
# [07/03 22:12:52] __main__ INFO: Epoch: 70 , Validation Loss: 154.07210086286068 , Validation Accuracy: 0.8118 , Test Loss: 6.878393113613129 , Test Accuracy: 0.8018 , Timing: 6.219297885894775
# [07/03 22:13:05] __main__ INFO: Epoch: 71 , Validation Loss: 199.15770508348942 , Validation Accuracy: 0.7618 , Test Loss: 7.563138842582703 , Test Accuracy: 0.7901 , Timing: 6.193436622619629
# [07/03 22:13:18] __main__ INFO: Epoch: 72 , Validation Loss: 176.36959251761436 , Validation Accuracy: 0.792 , Test Loss: 6.8981088399887085 , Test Accuracy: 0.8117 , Timing: 6.198381423950195
# [07/03 22:13:31] __main__ INFO: Epoch: 73 , Validation Loss: 176.26007768511772 , Validation Accuracy: 0.79 , Test Loss: 7.255272269248962 , Test Accuracy: 0.7948 , Timing: 6.321364879608154
# [07/03 22:13:44] __main__ INFO: Epoch: 74 , Validation Loss: 178.88265956565738 , Validation Accuracy: 0.7956 , Test Loss: 7.154244661331177 , Test Accuracy: 0.8053 , Timing: 6.1752610206604
# [07/03 22:13:57] __main__ INFO: Epoch: 75 , Validation Loss: 179.8962598182261 , Validation Accuracy: 0.7916 , Test Loss: 7.011789977550507 , Test Accuracy: 0.8095 , Timing: 6.170836448669434
# [07/03 22:14:10] __main__ INFO: Epoch: 76 , Validation Loss: 186.78867477923632 , Validation Accuracy: 0.7804 , Test Loss: 7.506693363189697 , Test Accuracy: 0.7912 , Timing: 6.341845750808716
# [07/03 22:14:23] __main__ INFO: Epoch: 77 , Validation Loss: 192.18656085431576 , Validation Accuracy: 0.7756 , Test Loss: 7.7223052978515625 , Test Accuracy: 0.791 , Timing: 6.196389198303223
# [07/03 22:14:35] __main__ INFO: Epoch: 78 , Validation Loss: 198.9035922959447 , Validation Accuracy: 0.7732 , Test Loss: 7.987277150154114 , Test Accuracy: 0.7873 , Timing: 6.184866905212402
# [07/03 22:14:48] __main__ INFO: Epoch: 79 , Validation Loss: 178.50297491066158 , Validation Accuracy: 0.7994 , Test Loss: 7.264247179031372 , Test Accuracy: 0.8053 , Timing: 6.180140972137451
# [07/03 22:15:21] __main__ INFO: Epoch: 121, GLISTER dataloader subset selection finished, takes 32.7484.
# [07/03 22:15:34] __main__ INFO: Epoch: 80 , Validation Loss: 131.11169830709696 , Validation Accuracy: 0.8156 , Test Loss: 5.370713114738464 , Test Accuracy: 0.8132 , Timing: 38.93191576004028
# [07/03 22:15:34] __main__ INFO: Model checkpoint saved at epoch: 80
# [07/03 22:15:47] __main__ INFO: Epoch: 81 , Validation Loss: 136.21838727593422 , Validation Accuracy: 0.8178 , Test Loss: 5.479500949382782 , Test Accuracy: 0.8167 , Timing: 6.179960489273071
# [07/03 22:16:00] __main__ INFO: Epoch: 82 , Validation Loss: 136.54096388816833 , Validation Accuracy: 0.8134 , Test Loss: 5.5327675342559814 , Test Accuracy: 0.8111 , Timing: 6.156244277954102
# [07/03 22:16:12] __main__ INFO: Epoch: 83 , Validation Loss: 128.98988502845168 , Validation Accuracy: 0.8184 , Test Loss: 5.363359600305557 , Test Accuracy: 0.824 , Timing: 6.203386545181274
# [07/03 22:16:25] __main__ INFO: Epoch: 84 , Validation Loss: 133.00585969164968 , Validation Accuracy: 0.8274 , Test Loss: 5.4050107300281525 , Test Accuracy: 0.8256 , Timing: 6.176747560501099
# [07/03 22:16:38] __main__ INFO: Epoch: 85 , Validation Loss: 135.12082783132792 , Validation Accuracy: 0.82 , Test Loss: 5.711461067199707 , Test Accuracy: 0.8239 , Timing: 6.2529826164245605
# [07/03 22:16:52] __main__ INFO: Epoch: 86 , Validation Loss: 140.9874446541071 , Validation Accuracy: 0.8204 , Test Loss: 5.808779299259186 , Test Accuracy: 0.8196 , Timing: 6.168976783752441
# [07/03 22:17:05] __main__ INFO: Epoch: 87 , Validation Loss: 135.2252593152225 , Validation Accuracy: 0.8284 , Test Loss: 5.697792828083038 , Test Accuracy: 0.8291 , Timing: 6.206789493560791
# [07/03 22:17:18] __main__ INFO: Epoch: 88 , Validation Loss: 167.91273407638073 , Validation Accuracy: 0.7904 , Test Loss: 7.212896704673767 , Test Accuracy: 0.7944 , Timing: 6.204271554946899
# [07/03 22:17:30] __main__ INFO: Epoch: 89 , Validation Loss: 139.06351585686207 , Validation Accuracy: 0.824 , Test Loss: 5.92263126373291 , Test Accuracy: 0.8247 , Timing: 6.205137252807617
# [07/03 22:17:43] __main__ INFO: Epoch: 90 , Validation Loss: 143.31592125445604 , Validation Accuracy: 0.8304 , Test Loss: 5.759111702442169 , Test Accuracy: 0.8341 , Timing: 6.177870512008667
# [07/03 22:17:56] __main__ INFO: Epoch: 91 , Validation Loss: 159.78597430884838 , Validation Accuracy: 0.809 , Test Loss: 6.526841878890991 , Test Accuracy: 0.8186 , Timing: 6.182222843170166
# [07/03 22:18:09] __main__ INFO: Epoch: 92 , Validation Loss: 138.95946210250258 , Validation Accuracy: 0.8338 , Test Loss: 5.671689480543137 , Test Accuracy: 0.838 , Timing: 6.1540303230285645
# [07/03 22:18:22] __main__ INFO: Epoch: 93 , Validation Loss: 154.40058295428753 , Validation Accuracy: 0.818 , Test Loss: 6.220317900180817 , Test Accuracy: 0.8295 , Timing: 6.175783395767212
# [07/03 22:18:34] __main__ INFO: Epoch: 94 , Validation Loss: 170.68058636784554 , Validation Accuracy: 0.8042 , Test Loss: 7.006101489067078 , Test Accuracy: 0.8096 , Timing: 6.133573293685913
# [07/03 22:18:47] __main__ INFO: Epoch: 95 , Validation Loss: 162.26832560822368 , Validation Accuracy: 0.814 , Test Loss: 6.711236536502838 , Test Accuracy: 0.8194 , Timing: 6.225920677185059
# [07/03 22:19:00] __main__ INFO: Epoch: 96 , Validation Loss: 146.53699015825987 , Validation Accuracy: 0.8296 , Test Loss: 6.233709394931793 , Test Accuracy: 0.8313 , Timing: 6.215796232223511
# [07/03 22:19:13] __main__ INFO: Epoch: 97 , Validation Loss: 171.51883232593536 , Validation Accuracy: 0.8112 , Test Loss: 7.29659640789032 , Test Accuracy: 0.808 , Timing: 6.244813680648804
# [07/03 22:19:26] __main__ INFO: Epoch: 98 , Validation Loss: 167.01097776181996 , Validation Accuracy: 0.8192 , Test Loss: 6.978147745132446 , Test Accuracy: 0.8181 , Timing: 6.1613450050354
# [07/03 22:19:39] __main__ INFO: Epoch: 99 , Validation Loss: 177.61901779472828 , Validation Accuracy: 0.8116 , Test Loss: 7.731545269489288 , Test Accuracy: 0.8095 , Timing: 6.14387583732605
# [07/03 22:20:11] __main__ INFO: Epoch: 141, GLISTER dataloader subset selection finished, takes 32.5602.
# [07/03 22:20:24] __main__ INFO: Epoch: 100 , Validation Loss: 127.99118122458458 , Validation Accuracy: 0.8198 , Test Loss: 5.092173784971237 , Test Accuracy: 0.8228 , Timing: 38.76006579399109
# [07/03 22:20:24] __main__ INFO: Model checkpoint saved at epoch: 100
# [07/03 22:20:24] __main__ INFO: GLISTER Selection Run---------------------------------
# [07/03 22:20:24] __main__ INFO: Final SubsetTrn: 224.082257
# [07/03 22:20:24] __main__ INFO: Validation Loss: 127.99 , Validation Accuracy: 0.82
# [07/03 22:20:24] __main__ INFO: Test Loss: 5.09, Test Accuracy: 0.82
# [07/03 22:20:24] __main__ INFO: ---------------------------------------------------------------------
# [07/03 22:20:24] __main__ INFO: GLISTER
# [07/03 22:20:24] __main__ INFO: ---------------------------------------------------------------------
# [07/03 22:20:24] __main__ INFO: Validation Accuracy,  , 0.734 , 0.6692 , 0.6936 , 0.701 , 0.7262 , 0.7302 , 0.737 , 0.7234 , 0.737 , 0.7088 , 0.7252 , 0.7104 , 0.736 , 0.7518 , 0.7502 , 0.675 , 0.735 , 0.7222 , 0.7064 , 0.7458 , 0.7618 , 0.761 , 0.7542 , 0.7558 , 0.7744 , 0.7234 , 0.7648 , 0.7286 , 0.7342 , 0.7398 , 0.7262 , 0.766 , 0.755 , 0.7812 , 0.7308 , 0.7438 , 0.735 , 0.733 , 0.7366 , 0.7886 , 0.7542 , 0.7716 , 0.7874 , 0.7818 , 0.7698 , 0.7672 , 0.7846 , 0.784 , 0.7988 , 0.7992 , 0.7698 , 0.7846 , 0.7932 , 0.7942 , 0.7854 , 0.7636 , 0.7874 , 0.7876 , 0.7484 , 0.8034 , 0.802 , 0.7992 , 0.8096 , 0.7876 , 0.8118 , 0.7892 , 0.7948 , 0.7922 , 0.7672 , 0.8118 , 0.7618 , 0.792 , 0.79 , 0.7956 , 0.7916 , 0.7804 , 0.7756 , 0.7732 , 0.7994 , 0.8156 , 0.8178 , 0.8134 , 0.8184 , 0.8274 , 0.82 , 0.8204 , 0.8284 , 0.7904 , 0.824 , 0.8304 , 0.809 , 0.8338 , 0.818 , 0.8042 , 0.814 , 0.8296 , 0.8112 , 0.8192 , 0.8116 , 0.8198
# [07/03 22:20:24] __main__ INFO: Test Accuracy,  , 0.7405 , 0.6906 , 0.7128 , 0.7144 , 0.7391 , 0.7368 , 0.746 , 0.7367 , 0.7497 , 0.7219 , 0.7301 , 0.7264 , 0.7401 , 0.7459 , 0.7566 , 0.6921 , 0.7454 , 0.7341 , 0.7289 , 0.7519 , 0.7584 , 0.7602 , 0.7615 , 0.7571 , 0.7824 , 0.7356 , 0.7708 , 0.741 , 0.7372 , 0.7516 , 0.72 , 0.7573 , 0.7597 , 0.7865 , 0.7231 , 0.7612 , 0.7384 , 0.7367 , 0.7313 , 0.7935 , 0.7589 , 0.7756 , 0.7866 , 0.7916 , 0.7848 , 0.7724 , 0.784 , 0.7918 , 0.8055 , 0.8057 , 0.7685 , 0.7774 , 0.7951 , 0.8074 , 0.7941 , 0.7818 , 0.7983 , 0.8 , 0.7528 , 0.8165 , 0.8042 , 0.8018 , 0.8106 , 0.799 , 0.8129 , 0.7973 , 0.8006 , 0.7913 , 0.7767 , 0.8018 , 0.7901 , 0.8117 , 0.7948 , 0.8053 , 0.8095 , 0.7912 , 0.791 , 0.7873 , 0.8053 , 0.8132 , 0.8167 , 0.8111 , 0.824 , 0.8256 , 0.8239 , 0.8196 , 0.8291 , 0.7944 , 0.8247 , 0.8341 , 0.8186 , 0.838 , 0.8295 , 0.8096 , 0.8194 , 0.8313 , 0.808 , 0.8181 , 0.8095 , 0.8228
# [07/03 22:20:24] __main__ INFO: [6.224469184875488, 6.194570779800415, 6.205414772033691, 6.1725358963012695, 6.146477460861206, 6.173302173614502, 6.173976182937622, 6.176623344421387, 6.20458984375, 6.239851951599121, 6.1872429847717285, 6.164392471313477, 6.153202533721924, 6.476832389831543, 6.182268381118774, 6.228482723236084, 6.206922769546509, 6.140637159347534, 6.1667046546936035, 39.64784622192383, 6.3326098918914795, 6.18815541267395, 6.2116546630859375, 6.184006452560425, 6.205666542053223, 6.180716276168823, 6.255231857299805, 6.227575778961182, 6.1820783615112305, 6.184403896331787, 6.168573617935181, 6.4507434368133545, 6.19563364982605, 6.215059041976929, 6.259663343429565, 6.192409992218018, 6.17082667350769, 6.148425579071045, 6.156507968902588, 38.993733644485474, 6.161468744277954, 6.143886089324951, 6.1695778369903564, 6.168063163757324, 6.193114995956421, 6.228784084320068, 6.19180154800415, 6.140308618545532, 6.1957197189331055, 6.366339683532715, 6.156532526016235, 6.24145770072937, 6.199109792709351, 6.220349311828613, 6.169164180755615, 6.157003879547119, 6.160642147064209, 6.1885809898376465, 6.229471921920776, 38.77840065956116, 6.14604377746582, 6.187392950057983, 6.146167039871216, 6.172006607055664, 6.1962504386901855, 6.159686088562012, 6.148575305938721, 6.165439128875732, 6.170447587966919, 6.219297885894775, 6.193436622619629, 6.198381423950195, 6.321364879608154, 6.1752610206604, 6.170836448669434, 6.341845750808716, 6.196389198303223, 6.184866905212402, 6.180140972137451, 38.93191576004028, 6.179960489273071, 6.156244277954102, 6.203386545181274, 6.176747560501099, 6.2529826164245605, 6.168976783752441, 6.206789493560791, 6.204271554946899, 6.205137252807617, 6.177870512008667, 6.182222843170166, 6.1540303230285645, 6.175783395767212, 6.133573293685913, 6.225920677185059, 6.215796232223511, 6.244813680648804, 6.1613450050354, 6.14387583732605, 38.76006579399109]
# [07/03 22:20:24] __main__ INFO: Total time taken by GLISTER = 0.2178

# %%
print(f"Average Time / Epoch: {np.mean(timing)} \nTotal Epochs: {num_epochs}")
# Out:
# Average Time / Epoch: 7.839653375148774
# Total Epochs: 100

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Not connected to a GPU')
else:
  print(gpu_info)
# Out:
# Sun Jul  3 22:20:24 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   59C    P0    45W / 250W |   7411MiB / 16280MiB |      3%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# +-----------------------------------------------------------------------------+
